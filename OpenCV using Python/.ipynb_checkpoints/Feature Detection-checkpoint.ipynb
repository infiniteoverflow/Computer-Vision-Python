# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
template_image = cv2.imread('Images/mvit1.jpg',0)
template_image = template_image[100:300,150:600]
plt.imshow(template_image,cmap='gray')

# %%
target_image = cv2.imread('Images/mvit0.jpeg',0)
plt.imshow(target_image,cmap='gray')

# %% [markdown]
# ## Brute force Detection with ORB Descriptors

# %%
orb = cv2.ORB_create()

# %%
kp1,des1 = orb.detectAndCompute(template_image,None)
kp2,des2 = orb.detectAndCompute(target_image,None)

# %%
bf = cv2.BFMatcher(cv2.NORM_HAMMING,crossCheck=True)

# %%
matches = bf.match(des1,des2)

# %%
matches
# Out:
# [<DMatch 0x12b2df190>,
#  <DMatch 0x12b2df250>,
#  <DMatch 0x12b2df150>,
#  <DMatch 0x125464450>,
#  <DMatch 0x125464bf0>,
#  <DMatch 0x125464e10>,
#  <DMatch 0x1254649f0>,
#  <DMatch 0x125464fd0>,
#  <DMatch 0x1254646f0>,
#  <DMatch 0x125464e90>,
#  <DMatch 0x1254648f0>,
#  <DMatch 0x125464cd0>,
#  <DMatch 0x125c28990>,
#  <DMatch 0x125c28c30>,
#  <DMatch 0x125c28af0>,
#  <DMatch 0x125c28d30>,
#  <DMatch 0x1257c1150>,
#  <DMatch 0x1257c1230>,
#  <DMatch 0x1257c11b0>,
#  <DMatch 0x12a94f110>,
#  <DMatch 0x12a94f0d0>,
#  <DMatch 0x12a94f1b0>,
#  <DMatch 0x12a94f0f0>,
#  <DMatch 0x12a94f090>,
#  <DMatch 0x12a94f030>,
#  <DMatch 0x12a94f050>,
#  <DMatch 0x12a94f070>,
#  <DMatch 0x12a94f390>,
#  <DMatch 0x12a94f3d0>,
#  <DMatch 0x12a94f3b0>,
#  <DMatch 0x12a94f350>,
#  <DMatch 0x12a94f430>,
#  <DMatch 0x12a94f470>,
#  <DMatch 0x12a94f450>,
#  <DMatch 0x12a94f330>,
#  <DMatch 0x12a94f2d0>,
#  <DMatch 0x12a94f2b0>,
#  <DMatch 0x12a94f1f0>,
#  <DMatch 0x12a94f490>,
#  <DMatch 0x12a94f410>,
# ...

# %%
matches = sorted(matches,key=lambda x:x.distance)

# %%
template_matches = cv2.drawMatches(template_image,kp1,target_image,kp2,matches[:20],None,flags=2)

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(template_matches)

# %% [markdown]
# ## Brute Force Detection with SIFT Descriptors

# %%
sift = cv2.xfeatures2d.SIFT_create()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-2247b17ceab8> in <module>
# ----> 1 sift = cv2.xfeatures2d.SIFT_create()
#
# AttributeError: module 'cv2.cv2' has no attribute 'xfeatures2d'
