# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('Images/horse.jpeg')
img_cvt = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img_cvt)

# %%
result = cv2.calcHist([img],channels=[0],mask=None,histSize=[256],ranges=[0,256])

# %%
result
# Out:
# array([[4.5770e+03],
#        [8.8917e+04],
#        [2.0950e+03],
#        [2.0590e+03],
#        [1.3460e+03],
#        [1.3590e+03],
#        [1.2110e+03],
#        [9.8400e+02],
#        [7.8900e+02],
#        [6.3500e+02],
#        [6.8600e+02],
#        [5.8700e+02],
#        [6.0300e+02],
#        [6.1900e+02],
#        [6.5100e+02],
#        [7.0700e+02],
#        [6.5800e+02],
#        [6.6900e+02],
#        [6.3700e+02],
#        [6.3600e+02],
#        [6.9700e+02],
#        [6.3600e+02],
#        [5.8000e+02],
#        [5.6900e+02],
#        [5.2900e+02],
#        [5.4800e+02],
#        [5.0200e+02],
#        [5.0100e+02],
#        [4.2300e+02],
#        [4.1800e+02],
#        [4.0800e+02],
#        [4.1700e+02],
#        [3.9600e+02],
#        [3.8800e+02],
#        [3.4700e+02],
#        [3.5900e+02],
#        [3.5000e+02],
#        [3.3800e+02],
#        [3.2700e+02],
#        [3.1100e+02],
#        [3.0600e+02],
#        [2.8900e+02],
#        [3.0300e+02],
# ...

# %%
plt.plot(result)

# %%
result = cv2.calcHist([img_cvt],channels=[0],mask=None,histSize=[256],ranges=[0,256])

# %%
plt.plot(result)

# %%
col = ('b','g','r')

for i,color in enumerate(col):
    res = cv2.calcHist([img_cvt],channels=[i],mask=None,histSize=[256],ranges=[0,256])
    plt.plot(res)
    plt.xlim(0,50)
    plt.ylim(0,2500)

plt.title("Histogram of Horse")
# Out:
# Text(0.5, 1.0, 'Histogram of Horse')

# %%
plt.imshow(img[:,:,2])

# %%
dark_red = cv2.imread('Images/dark_red.jpg')
dark_red_cvt = cv2.cvtColor(dark_red,cv2.COLOR_BGR2RGB)
plt.imshow(dark_red_cvt)

# %%
dark_red_hist = cv2.calcHist([dark_red],channels=[2],mask=None,histSize=[256],ranges=[0,256])
plt.plot(dark_red_hist)

# %%
light_red = cv2.imread('Images/light_red.jpeg')
light_red_cvt = cv2.cvtColor(light_red,cv2.COLOR_BGR2RGB)
plt.imshow(light_red_cvt)

# %%
light_red_hist = cv2.calcHist([light_red],channels=[2],mask=None,histSize=[256],ranges=[0,256])
plt.plot(light_red_hist)

# %%
# Masking images and calculating Histogram for the given ROI

img = cv2.imread('Images/rainbow.jpg')
img_cvt = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img_cvt)

# %%
img.shape
# Out:
# (1333, 1333, 3)

# %%
mask = np.zeros(img.shape[:2],np.uint8)
mask_cvt = cv2.cvtColor(mask,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(mask_cvt)

# %%
mask[700:1000,600:1200] = 255

# %%
plt.imshow(mask,cmap='gray')

# %%
mask_img = cv2.bitwise_and(img,img,mask=mask)

# %%
plt.imshow(mask_img)

# %%
hist_rainbow_mask = cv2.calcHist([img],channels=[1],mask=mask,histSize=[256],ranges=[0,256])
hist_rainbow = cv2.calcHist([img],channels=[1],mask=None,histSize=[256],ranges=[0,256])

# %%
plt.plot(hist_rainbow_mask)

# %%
plt.plot(hist_rainbow)
